# %%
# Out:
# Linking to GEOS 3.7.2dev, GDAL 2.4.2, PROJ 6.1.0

# %%
library(tidyr)
library(readr)
library(plyr)
library(dplyr)
#library(stringr)
library(rgdal)
library(ggplot2)
library(sf)
# Out:
# Attaching package: ‘dplyr’
#
# The following objects are masked from ‘package:plyr’:
#
#     arrange, count, desc, failwith, id, mutate, rename, summarise,
#     summarize
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
#
# Loading required package: sp
# rgdal: version: 1.4-4, (SVN revision 833)
#  Geospatial Data Abstraction Library extensions to R successfully loaded
#  Loaded GDAL runtime: GDAL 2.4.2, released 2019/06/28
#  Path to GDAL shared files: /Users/enost/anaconda3/envs/r/share/gdal
#  GDAL binary built with GEOS: TRUE
#  Loaded PROJ.4 runtime: Rel. 6.1.0, May 15th, 2019, [PJ_VERSION: 610]
#  Path to PROJ.4 shared files: /Users/enost/anaconda3/envs/r/share/proj
#  Linking to sp version: 1.3-1
# Registered S3 methods overwritten by 'ggplot2':
#   method         from
#   [.quosures     rlang
#   c.quosures     rlang
#   print.quosures rlang
# Linking to GEOS 3.7.2dev, GDAL 2.4.2, PROJ 6.1.0

# %%
daily<-read_csv("https://raw.githubusercontent.com/ericnost/gfw/setup/data/2016-12-22.csv")
# Out:
# Parsed with column specification:
# cols(
#   date = col_date(format = ""),
#   lat_bin = col_double(),
#   lon_bin = col_double(),
#   mmsi = col_double(),
#   fishing_hours = col_double(),
#   lat = col_double(),
#   long = col_double(),
#   latlong = col_character()
# )

# %%
countries <- read_sf("https://raw.githubusercontent.com/ericnost/gfw/setup/data/countries.geojson")
wcpfc_map <- read_sf("https://raw.githubusercontent.com/ericnost/gfw/setup/data/wcpfc.geojson") 
spc <- read_sf("https://raw.githubusercontent.com/ericnost/gfw/setup/data/spc.geojson")

# %%
map = ggplot() + 
geom_sf(data = wcpfc_map, aes(fill = blue)) +
geom_sf(data = spc, aes(fill = green)) +
geom_sf(data = countries, aes(fill = NAME)) +
theme(legend.position = "none") 
map
# Out:
# plot without title

# %%
#load geographies
countries <- read_sf("https://raw.githubusercontent.com/ericnost/gfw/setup/data/countries.geojson")#readOGR(dsn="https://raw.githubusercontent.com/ericnost/gfw/setup/data/countries.geojson")
plot(countries, border="wheat3", col="wheat1")

wcpfc_map <- readOGR(dsn="https://raw.githubusercontent.com/ericnost/gfw/setup/data/wcpfc.geojson") #<- readOGR(dsn = "https://github.com/ericnost/gfw/tree/setup/shapefiles/Pacific", layer = "WCPFC") 
plot(wcpfc_map, border="wheat3", col="wheat2", add=T)

spc <- readOGR(dsn="https://raw.githubusercontent.com/ericnost/gfw/setup/data/spc.geojson")
plot(spc, border="wheat3", col="wheat3", add=T)
# Out:
# OGR data source with driver: GeoJSON
# Source: "https://raw.githubusercontent.com/ericnost/gfw/setup/data/countries.geojson", layer: "countries"
# with 255 features
# It has 94 fields
# OGR data source with driver: GeoJSON
# Source: "https://raw.githubusercontent.com/ericnost/gfw/setup/data/wcpfc.geojson", layer: "wcpfc"
# with 2 features
# It has 1 fields
# OGR data source with driver: GeoJSON
# Source: "https://raw.githubusercontent.com/ericnost/gfw/setup/data/spc.geojson", layer: "spc"
# with 2 features
# It has 1 fields
# plot without title

# %%
#load main vessel DB
vessels_full <- read_csv("https://raw.githubusercontent.com/ericnost/gfw/setup/data/vessels.csv")

#load WCPFC DB
wcpfc <- read_csv("https://raw.githubusercontent.com/ericnost/gfw/setup/data/RFV_database_export.csv")
# Out:
# Parsed with column specification:
# cols(
#   mmsi = col_double(),
#   shipname = col_character(),
#   callsign = col_character(),
#   flag = col_character(),
#   imo = col_logical(),
#   registry_geartype = col_character(),
#   inferred_geartype = col_character(),
#   inferred_geartype_score = col_double(),
#   inferred_subgeartype = col_character(),
#   inferred_subgeartype_score = col_double(),
#   registry_length = col_double(),
#   inferred_length = col_double(),
#   registry_tonnage = col_double(),
#   inferred_tonnage = col_double(),
#   registry_engine_power = col_double(),
#   inferred_engine_power = col_double(),
#   source = col_character()
# )
# Warning message:
# “12059 parsing failures.
#   row col           expected  actual                                                                    file
# 99627 imo 1/0/T/F/TRUE/FALSE 9829978 'https://raw.githubusercontent.com/ericnost/gfw/setup/data/vessels.csv'
# 99628 imo 1/0/T/F/TRUE/FALSE 9731107 'https://raw.githubusercontent.com/ericnost/gfw/setup/data/vessels.csv'
# 99629 imo 1/0/T/F/TRUE/FALSE 9814480 'https://raw.githubusercontent.com/ericnost/gfw/setup/data/vessels.csv'
# 99630 imo 1/0/T/F/TRUE/FALSE 9821902 'https://raw.githubusercontent.com/ericnost/gfw/setup/data/vessels.csv'
# 99631 imo 1/0/T/F/TRUE/FALSE 8670069 'https://raw.githubusercontent.com/ericnost/gfw/setup/data/vessels.csv'
# ..... ... .................. ....... .......................................................................
# See problems(...) for more details.
# ”Parsed with column specification:
# cols(
#   .default = col_character(),
#   VID = col_double(),
#   `Built in Year` = col_double(),
#   Crew = col_double(),
#   Length = col_double(),
#   `Moulded Depth` = col_double(),
#   Beam = col_double(),
#   Tonnage = col_number(),
#   `Engine Power` = col_double(),
#   `FishHold Capacity` = col_double(),
#   `IMO-LR` = col_double()
# )
# See spec(...) for full column specifications.

# %%
head(wcpfc)
# Out:
#   Submitted by CCM VID Vessel Name      Flag
# 1 China             2  LONG XING 607    China
# 2 China             3  LONG XING 608    China
# 3 China             4  QING YUAN YU 001 China
# 4 China             7  QING YUAN YU 004 China
# 5 China            11  QING YUAN YU 008 China
# 6 China            12  QING YUAN YU 009 China
#   Registration Number                WIN   Previous Names  Reg Port
# 1 (LIAO)CHUANDENG(JI)(2018)FT-200065 BZSQ8 NONE            Dalian
# 2 (LIAO)CHUANDENG(JI)(2018)FT-200066 BZSQ9 NONE            Dalian
# 3 (LU)CHUANDENG(JI)(2019)FT-200023   BZZP  FULL MESNS NO.1 Qingdao
# 4 (LU)CHUANDENG(JI)(2019)FT-200030   BZZP4 FULL MESNS NO.2 Qingdao
# 5 (LU)CHUANDENG(JI)(2019)FT-200031   BZZP8 FULL HOPE NO.1  Qingdao
# 6 (LU)CHUANDENG(JI)(2019)FT-200032   BZZP9 FULL HOPE NO.2  Qingdao
#   Owner Name
# 1 DALIAN OCEAN FISHING CO.,LTD.
# 2 DALIAN OCEAN FISHING CO.,LTD.
# 3 Qingdao Furui Fisheries Co.,LTD.
# 4 Qingdao Furui Fisheries Co.Ltd
# 5 Qingdao Furui Fisheries Co.Ltd
# 6 Qingdao Furui Fisheries Co.Ltd
#   Owner Address                                            ... Auth Period To
# 1 No.38 Changjiang Road, Zhongshan District, Dalian，China ... 31-Mar-20
# 2 No.38 Changjiang Road, Zhongshan District, Dalian，China ... 31-Mar-20
# 3 1502，NO.2 Building,19 Fuzhou Nan Road Qingdao,China     ... 31-Mar-20
# 4 1502，NO.2 Building,19 Fuzhou Nan Road Qingdao,China     ... 31-Mar-20
# 5 1502，NO.2 Building,19 Fuzhou Nan Road Qingdao,China     ... 31-Mar-20
# 6 1502，NO.2 Building,19 Fuzhou Nan Road Qingdao,China     ... 31-Mar-20
#   Purse seine vessel authorised to tranship at sea IMO-LR
# 1 Not specified                                    8682517
# 2 Not specified                                    8682529
# 3 Not specified                                    8662622
# 4 Not specified                                    8662634
# 5 Not specified                                    8662646
# 6 Not specified                                    8662658
#   Authorisation to tranship on the high seas Under Charter Charterer Name
# 1 YES                                        NO            NA
# 2 YES                                        NO            NA
# 3 YES                                        NO            NA
# 4 YES                                        NO            NA
# 5 YES                                        NO            NA
# 6 YES                                        NO            NA
#   Chartering CCM Address of Charter Charter Start Date Charter End Date
# 1 NA             NA                 NA                 NA
# 2 NA             NA                 NA                 NA
# 3 NA             NA                 NA                 NA
# 4 NA             NA                 NA                 NA
# 5 NA             NA                 NA                 NA
# 6 NA             NA                 NA                 NA

# %%
#Zoom in to Dongwon
#ky<-wcpfc[grep("KYOKUYO", wcpfc$`Owner Name`),] #5 vessels
dongwon<-wcpfc[grep("DONGW", wcpfc$`Owner Name`),] #44 vessels
dongwon
#merge dongwon and ky
#dongwon<-rbind(dongwon,ky)
# Out:
#    Submitted by CCM    VID   Vessel Name     Flag
# 1  Korea (Republic of)   434 NO.639 DONGWON  Korea (Republic of)
# 2  Korea (Republic of)   901 NO.617 DONG WON Korea (Republic of)
# 3  Korea (Republic of)   902 NO.618 DONG WON Korea (Republic of)
# 4  Korea (Republic of)   903 NO.619 DONG WON Korea (Republic of)
# 5  Korea (Republic of)   904 NO.620 DONG WON Korea (Republic of)
# 6  Korea (Republic of)   905 NO.621 DONG WON Korea (Republic of)
# 7  Korea (Republic of)   906 NO.622 DONG WON Korea (Republic of)
# 8  Korea (Republic of)   907 NO.623 DONG WON Korea (Republic of)
# 9  Korea (Republic of)   909 NO.637 DONG WON Korea (Republic of)
# 10 Korea (Republic of)   912 NO.631 DONG WON Korea (Republic of)
# 11 Korea (Republic of)   913 NO.632 DONG WON Korea (Republic of)
# 12 Korea (Republic of)   914 NO.633 DONG WON Korea (Republic of)
# 13 Korea (Republic of)  1663 COSMOS KIM      Korea (Republic of)
# 14 Korea (Republic of)  1667 BLUE OCEAN      Korea (Republic of)
# 15 Korea (Republic of)  1670 ELSPETH         Korea (Republic of)
# 16 Korea (Republic of)  1671 DEOLINDA        Korea (Republic of)
# 17 Korea (Republic of)  2105 NO.638 DONG WON Korea (Republic of)
# 18 Korea (Republic of)  2113 NO.117 DONGWON  Korea (Republic of)
# 24 4-Feb-21       Not applicable                                   9042013
# 25 28-May-19      Not applicable                                   8821541
# 26 21-Sep-20      Not applicable                                   8843111
# 27 21-Sep-20      Not applicable                                   8843094
# 28 27-Mar-24      Not applicable                                   8610631
# 29 18-Dec-20      Not applicable                                   8821553
# 30 2-Dec-19       Not applicable                                   8821565
# 31 6-Sep-24       Not applicable                                   9001423
# 32 24-Nov-22      No                                               8812227
# 33 20-Jul-24      No                                               8102854
# 34 2-Nov-23       No                                               9511301
# 35 28-Jun-21      No                                               9386665
# 36 24-Apr-24      NOT APPLICABLE                                   9036715
# 37 24-Mar-20      No                                               9163439
# 38 3-Jul-24       NOT APPLICABLE                                   9194919
# 39 16-Jul-24      No                                               9713973
# 40 10-Sep-24      No                                               9713985
# 41 28-Dec-20      NO                                               9743423
# 42 10-Feb-21      NO                                               9743435
# 43 8-Jul-24       NO                                               9848857
# 44 15-Sep-24      NO                                               9848869
#    Authorisation to tranship on the high seas Under Charter Charterer Name
# 1  YES                                        NO            NA
# 2  YES                                        NO            NA
# 3  YES                                        NO            NA
# 4  YES                                        NO            NA
# 5  YES                                        NO            NA
# 6  YES                                        NO            NA
# 7  YES                                        NO            NA
# 8  YES                                        NO            NA
# 9  YES                                        NO            NA
# 10 YES                                        NO            NA
# 11 YES                                        NO            NA
# 12 YES                                        NO            NA
# 13 No                                         NO            NA
# 14 No                                         NO            NA
# 15 No                                         NO            NA
# 16 No                                         NO            NA
# 17 YES                                        NO            NA
# 18 YES                                        NO            NA
# 19 YES                                        NO            NA
# 20 YES                                        NO            NA
# 21 YES                                        NO            NA
# 22 YES                                        NO            NA
# 23 YES                                        NO            NA
# 24 YES                                        NO            NA
# 25 YES                                        NO            NA
# 26 YES                                        NO            NA
# 27 YES                                        NO            NA
# 28 YES                                        NO            NA
# 29 YES                                        NO            NA
# 30 YES                                        NO            NA
# 31 YES                                        NO            NA
# 32 No                                         NO            NA
# 33 No                                         NO            NA
# 34 No                                         NO            NA
# 35 No                                         NO            NA
# 36 YES                                        NO            NA
# 37 YES                                        NO            NA
# 38 YES                                        NO            NA
# 39 No                                         NO            NA
# 40 No                                         NO            NA
# 41 NO                                         NO            NA
# 42 NO                                         NO            NA
# 43 NO                                         NO            NA
# 44 NO                                         NO            NA
#    Chartering CCM Address of Charter Charter Start Date Charter End Date
# 1  NA             NA                 NA                 NA
# 2  NA             NA                 NA                 NA
# 3  NA             NA                 NA                 NA
# 4  NA             NA                 NA                 NA
# 5  NA             NA                 NA                 NA
# 6  NA             NA                 NA                 NA
# 7  NA             NA                 NA                 NA
# 8  NA             NA                 NA                 NA
# 9  NA             NA                 NA                 NA
# 10 NA             NA                 NA                 NA
# 11 NA             NA                 NA                 NA
# 12 NA             NA                 NA                 NA
# 13 NA             NA                 NA                 NA
# 14 NA             NA                 NA                 NA
# 15 NA             NA                 NA                 NA
# 16 NA             NA                 NA                 NA
# 17 NA             NA                 NA                 NA
# 18 NA             NA                 NA                 NA
# 19 NA             NA                 NA                 NA
# 20 NA             NA                 NA                 NA
# 21 NA             NA                 NA                 NA
# 22 NA             NA                 NA                 NA
# 23 NA             NA                 NA                 NA
# 24 NA             NA                 NA                 NA
# 25 NA             NA                 NA                 NA
# 26 NA             NA                 NA                 NA
# 27 NA             NA                 NA                 NA
# 28 NA             NA                 NA                 NA
# 29 NA             NA                 NA                 NA
# 30 NA             NA                 NA                 NA
# 31 NA             NA                 NA                 NA
# 32 NA             NA                 NA                 NA
# 33 NA             NA                 NA                 NA
# 34 NA             NA                 NA                 NA
# 35 NA             NA                 NA                 NA
# 36 NA             NA                 NA                 NA
# 37 NA             NA                 NA                 NA
# 38 NA             NA                 NA                 NA
# 39 NA             NA                 NA                 NA
# 40 NA             NA                 NA                 NA
# 41 NA             NA                 NA                 NA
# 42 NA             NA                 NA                 NA
# 43 NA             NA                 NA                 NA
# 44 NA             NA                 NA                 NA

# %%
#Get the identifying info for Dongwon vessels, as described in the WCPFC RFV.
dongwon_imos<-dongwon$`IMO-LR`
dongwon_ircs<-dongwon$IRCS

filtered<-vessels_full[which(vessels_full$imo %in% dongwon_imos | vessels_full$callsign %in% dongwon_ircs ),]

dailies_filtered<-daily[which(daily$mmsi %in% filtered$mmsi),] #filtered to dongwon
dailies_extracted<-daily[-which(daily$mmsi %in% filtered$mmsi),] #all other vessels

# %%
#join vessels and effort
dongwon_fishing<-merge(dailies_filtered, filtered, by = "mmsi")
allother_fishing<-merge(dailies_extracted, vessels_full, by ="mmsi")
dongwon_fishing
# Out:
#     mmsi      date       lat_bin lon_bin fishing_hours lat    long
# 1   440195000 2016-12-22  -20     1741    0.4751389     -1.95  174.15
# 2   440233000 2016-12-22  -68    -1755    0.6090278     -6.75 -175.45
# 3   440233000 2016-12-22  -68    -1756    2.5755556     -6.75 -175.55
# 4   440233000 2016-12-22  -67    -1756    0.3052778     -6.65 -175.55
# 5   440233000 2016-12-22  -64    -1759    0.3650000     -6.35 -175.85
# 6   440236000 2016-12-22   81     -183    6.8979167      8.15  -18.25
# 7   440479000 2016-12-22  -20     1740    0.8443056     -1.95  174.05
# 8   440479000 2016-12-22  -20     1741    0.3725000     -1.95  174.15
# 9   440479000 2016-12-22  -19     1741    0.7208333     -1.85  174.15
# 10  440574000 2016-12-22  -27    -1574    0.4111111     -2.65 -157.35
# 11  440574000 2016-12-22  -27    -1578    2.1250000     -2.65 -157.75
# 12  440574000 2016-12-22  -26    -1576    1.8484722     -2.55 -157.55
# 13  440574000 2016-12-22  -26    -1573    1.6913889     -2.55 -157.25
# 14  440574000 2016-12-22  -26    -1577   10.8247222     -2.55 -157.65
# 15  440574000 2016-12-22  -26    -1574    1.4412500     -2.55 -157.35
# 16  440574000 2016-12-22  -28    -1579    0.9750000     -2.75 -157.85
# 17  440574000 2016-12-22  -26    -1575    2.7354167     -2.55 -157.45
# 18  440574000 2016-12-22  -29    -1579    3.5141667     -2.85 -157.85
# 19  440574000 2016-12-22  -28    -1578    0.5763889     -2.75 -157.75
# 20  440584000 2016-12-22 -126    -1175    1.9758333    -12.55 -117.45
# 246 -4.45, -176.55  OCEANACE   DTBQ5    ... 0.9986559
# 247 -14.85, 45.95   DONGWON637 DTBW8    ... 0.9999999
# 248 -14.55, 45.75   DONGWON637 DTBW8    ... 0.9999999
# 249 -14.55, 45.95   DONGWON637 DTBW8    ... 0.9999999
# 250 -14.45, 45.95   DONGWON637 DTBW8    ... 0.9999999
# 251 -14.45, 46.15   DONGWON637 DTBW8    ... 0.9999999
# 252 -14.45, 46.05   DONGWON637 DTBW8    ... 0.9999999
# 253 -14.45, 46.25   DONGWON637 DTBW8    ... 0.9999999
# 254 -14.35, 45.95   DONGWON637 DTBW8    ... 0.9999999
# 255 -14.35, 46.05   DONGWON637 DTBW8    ... 0.9999999
# 256 -14.35, 46.15   DONGWON637 DTBW8    ... 0.9999999
# 257 -14.35, 46.25   DONGWON637 DTBW8    ... 0.9999999
# 258 -14.75, 45.85   DONGWON637 DTBW8    ... 0.9999999
# 259 -14.75, 46.15   DONGWON637 DTBW8    ... 0.9999999
# 260 -14.65, 45.75   DONGWON637 DTBW8    ... 0.9999999
# 261 -14.55, 46.15   DONGWON637 DTBW8    ... 0.9999999
#     inferred_subgeartype inferred_subgeartype_score registry_length
# 1   purse_seines         0.8005054                  79.6000
# 2   purse_seines         0.9984821                  74.6630
# 3   purse_seines         0.9984821                  74.6630
# 4   purse_seines         0.9984821                  74.6630
# 5   purse_seines         0.9984821                  74.6630
# 6   drifting_longlines   0.9999995                  52.6204
# 7   purse_seines         0.9989618                  73.0490
# 8   purse_seines         0.9989618                  73.0490
# 9   purse_seines         0.9989618                  73.0490
# 10  drifting_longlines   1.0000000                  51.1420
# 11  drifting_longlines   1.0000000                  51.1420
# 12  drifting_longlines   1.0000000                  51.1420
# 13  drifting_longlines   1.0000000                  51.1420
# 14  drifting_longlines   1.0000000                  51.1420
# 15  drifting_longlines   1.0000000                  51.1420
# 16  drifting_longlines   1.0000000                  51.1420
# 17  drifting_longlines   1.0000000                  51.1420
# 18  drifting_longlines   1.0000000                  51.1420
# 19  drifting_longlines   1.0000000                  51.1420
# 20  drifting_longlines   0.9999999                  51.1420
# 21  drifting_longlines   0.9999999                  51.1420
# 22  drifting_longlines   0.9999999                  51.1420
# 23  drifting_longlines   0.9999999                  51.1420
# 24  drifting_longlines   0.9999999                  51.1420
# 25  drifting_longlines   0.9999999                  51.1420
# 26  drifting_longlines   0.9999999                  51.1420
# 27  drifting_longlines   0.9999999                  51.1420
# 28  drifting_longlines   0.9999999                  51.1420
# 29  drifting_longlines   0.9999999                  51.1420
# 30  drifting_longlines   0.9999999                  51.1420
# ... ...                  ...                        ...
# 232 drifting_longlines   1.0000000                  50.902
# 233 drifting_longlines   1.0000000                  50.902
# 234 drifting_longlines   1.0000000                  50.902
# 235 drifting_longlines   1.0000000                  50.902
# 236 drifting_longlines   1.0000000                  50.902
# 237 drifting_longlines   1.0000000                  50.902
# 238 drifting_longlines   1.0000000                  50.902
# 239 drifting_longlines   1.0000000                  50.902
# 240 drifting_longlines   1.0000000                  50.902
# 249 49.48023         NA               454.3757            NA
# 250 49.48023         NA               454.3757            NA
# 251 49.48023         NA               454.3757            NA
# 252 49.48023         NA               454.3757            NA
# 253 49.48023         NA               454.3757            NA
# 254 49.48023         NA               454.3757            NA
# 255 49.48023         NA               454.3757            NA
# 256 49.48023         NA               454.3757            NA
# 257 49.48023         NA               454.3757            NA
# 258 49.48023         NA               454.3757            NA
# 259 49.48023         NA               454.3757            NA
# 260 49.48023         NA               454.3757            NA
# 261 49.48023         NA               454.3757            NA
#     inferred_engine_power source
# 1   4028.1910             AIS,CLAV,FFA,ISSF,ITU,KOR,WCPFC
# 2   3079.8755             AIS,CLAV,FFA,ISSF,ITU,KOR,WCPFC
# 3   3079.8755             AIS,CLAV,FFA,ISSF,ITU,KOR,WCPFC
# 4   3079.8755             AIS,CLAV,FFA,ISSF,ITU,KOR,WCPFC
# 5   3079.8755             AIS,CLAV,FFA,ISSF,ITU,KOR,WCPFC
# 6    873.2205             AIS,CLAV,FFA,IATTC,ITU,KOR,WCPFC
# 7   2947.6311             AIS,CLAV,FFA,ISSF,ITU,KOR,WCPFC
# 8   2947.6311             AIS,CLAV,FFA,ISSF,ITU,KOR,WCPFC
# 9   2947.6311             AIS,CLAV,FFA,ISSF,ITU,KOR,WCPFC
# 10  1016.2043             AIS,CLAV,FFA,IATTC,ITU,KOR,WCPFC,REVIEW
# 11  1016.2043             AIS,CLAV,FFA,IATTC,ITU,KOR,WCPFC,REVIEW
# 12  1016.2043             AIS,CLAV,FFA,IATTC,ITU,KOR,WCPFC,REVIEW
# 13  1016.2043             AIS,CLAV,FFA,IATTC,ITU,KOR,WCPFC,REVIEW
# 14  1016.2043             AIS,CLAV,FFA,IATTC,ITU,KOR,WCPFC,REVIEW
# 15  1016.2043             AIS,CLAV,FFA,IATTC,ITU,KOR,WCPFC,REVIEW
# 16  1016.2043             AIS,CLAV,FFA,IATTC,ITU,KOR,WCPFC,REVIEW
# 17  1016.2043             AIS,CLAV,FFA,IATTC,ITU,KOR,WCPFC,REVIEW
# 18  1016.2043             AIS,CLAV,FFA,IATTC,ITU,KOR,WCPFC,REVIEW
# 19  1016.2043             AIS,CLAV,FFA,IATTC,ITU,KOR,WCPFC,REVIEW
# 20  1056.7204             AIS,CLAV,FFA,IATTC,ITU,KOR,WCPFC
# 21  1056.7204             AIS,CLAV,FFA,IATTC,ITU,KOR,WCPFC
# 22  1056.7204             AIS,CLAV,FFA,IATTC,ITU,KOR,WCPFC
# 23  1056.7204             AIS,CLAV,FFA,IATTC,ITU,KOR,WCPFC
# 24  1056.7204             AIS,CLAV,FFA,IATTC,ITU,KOR,WCPFC
# 25  1056.7204             AIS,CLAV,FFA,IATTC,ITU,KOR,WCPFC
# 26  1056.7204             AIS,CLAV,FFA,IATTC,ITU,KOR,WCPFC
# 27  1056.7204             AIS,CLAV,FFA,IATTC,ITU,KOR,WCPFC
# 28  1056.7204             AIS,CLAV,FFA,IATTC,ITU,KOR,WCPFC
# 29  1056.7204             AIS,CLAV,FFA,IATTC,ITU,KOR,WCPFC
# 30  1056.7204             AIS,CLAV,FFA,IATTC,ITU,KOR,WCPFC
# ... ...                   ...
# 232 1036.154              AIS,CLAV,FFA,IATTC,ITU,KOR,WCPFC,REVIEW
# 233 1036.154              AIS,CLAV,FFA,IATTC,ITU,KOR,WCPFC,REVIEW
# 234 1036.154              AIS,CLAV,FFA,IATTC,ITU,KOR,WCPFC,REVIEW
# 235 1036.154              AIS,CLAV,FFA,IATTC,ITU,KOR,WCPFC,REVIEW
# 236 1036.154              AIS,CLAV,FFA,IATTC,ITU,KOR,WCPFC,REVIEW
# 237 1036.154              AIS,CLAV,FFA,IATTC,ITU,KOR,WCPFC,REVIEW
# 238 1036.154              AIS,CLAV,FFA,IATTC,ITU,KOR,WCPFC,REVIEW
# 239 1036.154              AIS,CLAV,FFA,IATTC,ITU,KOR,WCPFC,REVIEW
# 240 1036.154              AIS,CLAV,FFA,IATTC,ITU,KOR,WCPFC,REVIEW
# 241 3916.330              AIS,FFA
# 242 3916.330              AIS,FFA
# 243 3916.330              AIS,FFA
# 244 3916.330              AIS,FFA
# 245 3916.330              AIS,FFA
# 246 3916.330              AIS,FFA
# 247 1005.942              AIS,CLAV,FFA,IATTC,ITU,KOR,WCPFC
# 248 1005.942              AIS,CLAV,FFA,IATTC,ITU,KOR,WCPFC
# 249 1005.942              AIS,CLAV,FFA,IATTC,ITU,KOR,WCPFC
# 250 1005.942              AIS,CLAV,FFA,IATTC,ITU,KOR,WCPFC
# 251 1005.942              AIS,CLAV,FFA,IATTC,ITU,KOR,WCPFC
# 252 1005.942              AIS,CLAV,FFA,IATTC,ITU,KOR,WCPFC
# 253 1005.942              AIS,CLAV,FFA,IATTC,ITU,KOR,WCPFC
# 254 1005.942              AIS,CLAV,FFA,IATTC,ITU,KOR,WCPFC
# 255 1005.942              AIS,CLAV,FFA,IATTC,ITU,KOR,WCPFC
# 256 1005.942              AIS,CLAV,FFA,IATTC,ITU,KOR,WCPFC
# 257 1005.942              AIS,CLAV,FFA,IATTC,ITU,KOR,WCPFC
# 258 1005.942              AIS,CLAV,FFA,IATTC,ITU,KOR,WCPFC
# 259 1005.942              AIS,CLAV,FFA,IATTC,ITU,KOR,WCPFC
# 260 1005.942              AIS,CLAV,FFA,IATTC,ITU,KOR,WCPFC
# 261 1005.942              AIS,CLAV,FFA,IATTC,ITU,KOR,WCPFC

# %%
#aggregate by lat/long and vessel - all others
aggregated<-allother_fishing %>%
  group_by(lat_bin, lon_bin) %>% #, flag #aggregated at specific lat long bins
  summarise(totalFishingHours=sum(fishing_hours), flags=n_distinct(flag), count=n_distinct(mmsi)) 
#aggregated = total fishing effort at this lat long, number of unique flags and mmsis at this lat long
aggregated$lat_bin<-(aggregated$lat_bin/10)+.05
aggregated$lon_bin<-(aggregated$lon_bin/10)+.05

#max - produce a set of points with the max ALL OTHER FISHING for each lat/lon bin and report the flag
aggregated_max<-allother_fishing %>%
  group_by(lat_bin, lon_bin, flag) %>% #aggregated at specific lat long bins and flags
  summarise(totalFishingHours=sum(fishing_hours)) 
aggregated_max<-aggregated_max %>% 
  group_by(lat_bin, lon_bin) %>%
  filter(totalFishingHours == max(totalFishingHours))  #max here 553 -365
#total fishing effort at this lat long and the country that did it
aggregated_max$lat_bin<-(aggregated_max$lat_bin/10)+.05
aggregated_max$lon_bin<-(aggregated_max$lon_bin/10)+.05

aggregated
aggregated_max
# Out:
#       lat_bin lon_bin totalFishingHours flags count
# 1     -77.75   178.45 1.5980556         1     1
# 2     -77.65   178.45 4.1262500         1     1
# 3     -77.55   178.45 2.4544444         1     1
# 4     -77.45   178.45 4.1748611         1     1
# 5     -77.35   178.45 0.7490278         1     1
# 6     -77.25   179.25 0.6945833         1     1
# 7     -77.25   179.35 1.6205556         1     1
# 8     -77.15   179.35 3.2358333         1     1
# 9     -75.95  -171.85 1.5927778         1     1
# 10    -75.95  -171.65 1.6194444         1     1
# 15    -75.85  -171.45 RUS  0.8581944
# 16    -75.85  -171.35 RUS  1.5875000
# 17    -75.85  -171.15 RUS  1.6538889
# 18    -75.45  -174.35 SHN  1.6134722
# 19    -75.35  -174.75 SHN  0.9511111
# 20    -75.35  -174.65 SHN  0.8736111
# 21    -75.35  -174.55 SHN  1.6262500
# 22    -75.35  -174.45 SHN  1.6101389
# 23    -75.25  -175.35 SHN  1.7916667
# 24    -75.25  -175.25 SHN  2.1645833
# 25    -75.25  -175.15 SHN  2.4997222
# 26    -75.25  -175.05 SHN  1.0304167
# 27    -75.25  -174.95 SHN  3.9625000
# 28    -75.25  -174.85 SHN  1.6083333
# 29    -75.05  -176.55 KOR  1.5279167
# 30    -75.05  -176.35 KOR  0.1166667
# ...   ...     ...     ...  ...
# 16216 79.15   11.65   EST   5.3394444
# 16217 79.15   11.75   EST  11.8204167
# 16218 79.15   11.85   EST   0.4945833
# 16219 79.25    8.55   RUS   4.8369444
# 16220 79.25    8.65   RUS   4.9244444
# 16221 79.25    8.75   RUS   4.0766667
# 16222 79.25    8.85   RUS   1.7545833
# 16223 79.25   11.75   EST   1.4568056
# 16224 79.25   11.85   EST   0.5776389
# 16225 79.35    8.25   RUS   0.8408333
# 16226 79.35    8.35   RUS   7.2165278
# 16227 79.35    8.45   RUS   8.3297222
# 16228 79.35    8.55   RUS   2.4880556
# 16229 79.35    8.75   RUS   0.7679167
# 16230 79.45    8.45   RUS   4.0023611
# 16231 79.45    8.65   RUS   1.6475000
# 16232 79.55   18.55   LTU   0.8129167
# 16233 79.55   18.65   LTU   1.6230556
# 16234 79.65   18.15   LTU   2.3762500
# 16235 79.65   18.25   LTU   2.5693056
# 16236 79.65   18.35   LTU   1.5630556
# 16237 79.65   18.45   LTU   1.5973611
# 16238 79.65   18.55   LTU   3.3834722
# 16239 79.75   17.95   LTU   0.7945833
# 16240 79.75   18.05   LTU   4.0481944
# 16241 79.75   18.15   LTU   4.8666667
# 16242 80.65   28.55   EST   1.5780556
# 16243 80.65   28.65   EST   0.8625000
# 16244 80.75   28.75   EST   3.2456944
# 16245 80.75   28.85   EST   3.3376389

# %%
#aggregate by lat/long and vessel - - Dongwon
dongwon_aggregated<-dongwon_fishing %>%
  group_by(lat_bin, lon_bin) %>% #aggregated at specific lat long bins
  summarise(totalFishingHours=sum(fishing_hours), flag="DONG", count=n_distinct(mmsi)) 
#total fishing effort at this lat long, number of unique Dongwon mmsis at this lat long
dongwon_aggregated$lat_bin<-(dongwon_aggregated$lat_bin/10)+.05
dongwon_aggregated$lon_bin<-(dongwon_aggregated$lon_bin/10)+.05
dongwon_aggregated
# Out:
#     lat_bin lon_bin totalFishingHours flag count
# 1   -14.85    45.95 1.6547222         DONG 1
# 2   -14.75    45.85 1.8319444         DONG 1
# 3   -14.75    46.15 1.1752778         DONG 1
# 4   -14.65    45.75 2.9165278         DONG 1
# 5   -14.55    45.75 0.8665278         DONG 1
# 6   -14.55    45.95 0.9012500         DONG 1
# 7   -14.55    46.15 0.7481944         DONG 1
# 8   -14.45    45.95 2.0776389         DONG 1
# 9   -14.45    46.05 0.6525000         DONG 1
# 10  -14.45    46.15 0.7959722         DONG 1
# 11  -14.45    46.25 4.1712500         DONG 1
# 12  -14.35    45.95 0.7986111         DONG 1
# 13  -14.35    46.05 0.9791667         DONG 1
# 14  -14.35    46.15 1.4381944         DONG 1
# 15  -14.35    46.25 1.0877778         DONG 1
# 16  -14.25  -114.15 0.3150000         DONG 1
# 17  -14.15  -114.15 2.4240278         DONG 1
# 18  -14.05  -114.25 0.4036111         DONG 1
# 19  -14.05  -114.15 1.6112500         DONG 1
# 20  -13.95  -114.15 1.5813889         DONG 1
# 21  -13.85  -114.15 1.7668056         DONG 1
# 22  -13.75  -114.35 0.3658333         DONG 1
# 23  -13.75  -114.15 1.7512500         DONG 1
# 24  -13.65  -114.35 0.4898611         DONG 1
# 25  -13.65  -114.15 1.8023611         DONG 1
# 26  -13.55  -114.55 0.6958333         DONG 1
# 27  -13.55  -114.25 0.1790278         DONG 1
# 28  -13.55  -114.15 3.0086111         DONG 1
# 29  -13.45  -115.05 2.0363889         DONG 1
# 30  -13.45  -114.95 0.5633333         DONG 1
# ... ...     ...     ...               ...  ...
# 193 0.35    -170.45  4.9123611        DONG 1
# 194 0.35    -169.85  2.3297222        DONG 1
# 195 0.45    -169.85  1.4756944        DONG 1
# 196 0.55    -169.85  1.5268056        DONG 1
# 197 0.65    -169.85  0.6976389        DONG 1
# 198 0.65    -169.75  0.6952778        DONG 1
# 199 0.75    -169.75  1.0020833        DONG 1
# 200 0.85    -170.45 11.9251389        DONG 1
# 201 0.85    -170.35  5.8494444        DONG 1
# 202 0.85    -169.85  0.2915278        DONG 1
# 203 0.95    -170.35  0.8256944        DONG 1
# 204 0.95    -169.85  0.1611111        DONG 1
# 205 1.05    -170.75  2.1512500        DONG 1
# 206 1.05    -170.65  0.9636111        DONG 1
# 207 1.05    -170.55  1.0255556        DONG 1
# 208 1.05    -170.45  0.4277778        DONG 1
# 209 1.15    -170.75  0.5888889        DONG 1
# 210 1.15    -170.45  5.2250000        DONG 1
# 211 2.25    -173.15  4.9322222        DONG 1
# 212 2.35    -173.05  0.8322222        DONG 1
# 213 2.35    -172.95  0.8387500        DONG 1
# 214 2.35    -172.55  4.6783333        DONG 1
# 215 2.45    -172.85  0.8012500        DONG 1
# 216 2.45    -172.55  0.8630556        DONG 1
# 217 2.55    -172.75  0.8447222        DONG 1
# 218 2.55    -172.55  0.8262500        DONG 1
# 219 2.65    -172.45  5.0923611        DONG 1
# 220 3.05    -171.35  4.5966667        DONG 1
# 221 3.05    -171.25  8.1000000        DONG 1
# 222 8.15     -18.25  6.8979167        DONG 1

# %%
#dongwon and all other together maxed.... 
#This will help us show the biggest flag or company (Dongwon) for each lat/long bin
dongwon_aggregated<-dongwon_aggregated[,-c(5)]
colnames(dongwon_aggregated)<-c("lat_bin", "lon_bin", "totalFishingHours", "flag")
total<-rbind(aggregated_max, dongwon_aggregated)
total<-total %>% 
  group_by(lat_bin, lon_bin) %>%
  filter(totalFishingHours == max(totalFishingHours)) 
total
# Out:
#       lat_bin lon_bin flag totalFishingHours
# 1     -77.75   178.45 UKR  1.5980556
# 2     -77.65   178.45 UKR  4.1262500
# 3     -77.55   178.45 UKR  2.4544444
# 4     -77.45   178.45 UKR  4.1748611
# 5     -77.35   178.45 UKR  0.7490278
# 6     -77.25   179.25 UKR  0.6945833
# 7     -77.25   179.35 UKR  1.6205556
# 8     -77.15   179.35 UKR  3.2358333
# 9     -75.95  -171.85 RUS  1.5927778
# 10    -75.95  -171.65 RUS  1.6194444
# 11    -75.95  -171.55 RUS  0.7959722
# 12    -75.95  -170.35 RUS  0.7098611
# 13    -75.85  -171.95 RUS  1.5959722
# 14    -75.85  -171.55 RUS  1.9327778
# 15    -75.85  -171.45 RUS  0.8581944
# 16    -75.85  -171.35 RUS  1.5875000
# 17    -75.85  -171.15 RUS  1.6538889
# 18    -75.45  -174.35 SHN  1.6134722
# 19    -75.35  -174.75 SHN  0.9511111
# 20    -75.35  -174.65 SHN  0.8736111
# 21    -75.35  -174.55 SHN  1.6262500
# 22    -75.35  -174.45 SHN  1.6101389
# 23    -75.25  -175.35 SHN  1.7916667
# 24    -75.25  -175.25 SHN  2.1645833
# 25    -75.25  -175.15 SHN  2.4997222
# 26    -75.25  -175.05 SHN  1.0304167
# 27    -75.25  -174.95 SHN  3.9625000
# 28    -75.25  -174.85 SHN  1.6083333
# 29    -75.05  -176.55 KOR  1.5279167
# 30    -75.05  -176.35 KOR  0.1166667
# ...   ...     ...     ...  ...
# 16417 0.15    -170.45 DONG  0.8126389
# 16418 0.25    -170.45 DONG  0.5941667
# 16419 0.35    -170.45 DONG  4.9123611
# 16420 0.35    -169.85 DONG  2.3297222
# 16421 0.45    -169.85 DONG  1.4756944
# 16422 0.55    -169.85 DONG  1.5268056
# 16423 0.65    -169.85 DONG  0.6976389
# 16424 0.65    -169.75 DONG  0.6952778
# 16425 0.85    -170.45 DONG 11.9251389
# 16426 0.85    -170.35 DONG  5.8494444
# 16427 0.85    -169.85 DONG  0.2915278
# 16428 0.95    -170.35 DONG  0.8256944
# 16429 0.95    -169.85 DONG  0.1611111
# 16430 1.05    -170.75 DONG  2.1512500
# 16431 1.05    -170.65 DONG  0.9636111
# 16432 1.05    -170.55 DONG  1.0255556
# 16433 1.05    -170.45 DONG  0.4277778
# 16434 1.15    -170.45 DONG  5.2250000
# 16435 2.25    -173.15 DONG  4.9322222
# 16436 2.35    -173.05 DONG  0.8322222
# 16437 2.35    -172.95 DONG  0.8387500
# 16438 2.35    -172.55 DONG  4.6783333
# 16439 2.45    -172.85 DONG  0.8012500
# 16440 2.45    -172.55 DONG  0.8630556
# 16441 2.55    -172.75 DONG  0.8447222
# 16442 2.55    -172.55 DONG  0.8262500
# 16443 2.65    -172.45 DONG  5.0923611
# 16444 3.05    -171.35 DONG  4.5966667
# 16445 3.05    -171.25 DONG  8.1000000
# 16446 8.15     -18.25 DONG  6.8979167

# %%
# Output
write_csv(aggregated, "all_other_fishing_total.csv")
write_csv(aggregated_max, "all_other_fishing_max.csv")
#write_csv(aggflag, "allotherfishing-specificflags-TOTAL.csv")
write_csv(dongwon_aggregated, "dongwon.csv")
write_csv(total, "all_fishing_max.csv")

# %%
# create points out of total data
total_pts = st_as_sf(total, coords = c("lon_bin", "lat_bin"), crs = 4326)

# %%
#standardize the CRS
#st_transform(total, crs = 4326)
wcpfc_map<-st_transform(wcpfc_map, crs = 4326)
spc<-st_transform(spc, crs = 4326)
countries<-st_transform(countries, crs = 4326)

# %%
#clip
clipped_total<-st_intersection(total_pts, st_buffer(spc, 0))
clipped_total
# Out:
# Warning message in st_buffer.sfc(st_geometry(x), dist, nQuadSegs, endCapStyle = endCapStyle, :
# “st_buffer does not correctly buffer longitude/latitude data”dist is assumed to be in decimal degrees (arc_degrees).
# although coordinates are longitude/latitude, st_intersection assumes that they are planar
# Warning message:
# “attribute variables are assumed to be spatially constant throughout all geometries”ERROR while rich displaying an object: Error in loadNamespace(name): there is no package called ‘geojsonio’
#
# Traceback:
# 1. FUN(X[[i]], ...)
# 2. tryCatch(withCallingHandlers({
#  .     if (!mime %in% names(repr::mime2repr))
#  .         stop("No repr_* for mimetype ", mime, " in repr::mime2repr")
#  .     rpr <- repr::mime2repr[[mime]](obj)
#  .     if (is.null(rpr))
#  .         return(NULL)
#  .     prepare_content(is.raw(rpr), rpr)
#  . }, error = error_handler), error = outer_handler)
# 3. tryCatchList(expr, classes, parentenv, handlers)
# 4. tryCatchOne(expr, names, parentenv, handlers[[1L]])
# 5. doTryCatch(return(expr), name, parentenv, handler)
# 6. withCallingHandlers({
#  .     if (!mime %in% names(repr::mime2repr))
#  .         stop("No repr_* for mimetype ", mime, " in repr::mime2repr")
#  .     rpr <- repr::mime2repr[[mime]](obj)
#  .     if (is.null(rpr))
#  .         return(NULL)
#  .     prepare_content(is.raw(rpr), rpr)
#  . }, error = error_handler)
# 7. repr::mime2repr[[mime]](obj)
# 8. repr_geojson.sf(obj)
# 9. repr_geojson(geojsonio::geojson_list(obj), ...)
# 10. geojsonio::geojson_list
# 11. getExportedValue(pkg, name)
# 12. asNamespace(ns)
# 13. getNamespace(ns)
# 14. loadNamespace(name)
# 15. withRestarts(stop(cond), retry_loadNamespace = function() NULL)
# 16. withOneRestart(expr, restarts[[1L]])
# 17. doWithOneRestart(return(expr), restart)
#     flag totalFishingHours RFB geometry
# 1   CHN   5.5408333        SPC POINT (170.95 -16.95)
# 2   FJI   0.8402778        SPC POINT (173.05 -16.95)
# 3   CHN   8.2180556        SPC POINT (173.25 -16.95)
# 4   FJI   2.7070833        SPC POINT (175.95 -16.95)
# 5   FJI   6.1620833        SPC POINT (179.75 -16.95)
# 6   TWN  12.1388889        SPC POINT (153.95 15.35)
# 7   TWN   6.5061111        SPC POINT (154.15 15.35)
# 8   TWN   6.1422222        SPC POINT (154.25 15.35)
# 9   TWN   3.0729167        SPC POINT (164.25 15.75)
# 10  TWN  17.0445833        SPC POINT (140.45 16.15)
# 11  TWN   3.9598611        SPC POINT (139.75 16.55)
# 12  TWN   9.7734722        SPC POINT (141.35 16.65)
# 13  CHN   6.1070833        SPC POINT (153.15 16.65)
# 14  CHN   5.7520833        SPC POINT (153.25 16.75)
# 15  TWN   4.3715278        SPC POINT (141.55 16.85)
# 16  TWN  16.6206944        SPC POINT (140.85 16.95)
# 17  TWN   8.6815278        SPC POINT (140.05 17.05)
# 18  TWN   6.2191667        SPC POINT (140.15 17.05)
# 19  TWN   7.7016667        SPC POINT (140.45 17.05)
# 20  TWN   8.2009722        SPC POINT (138.05 17.15)
# 21  TWN   5.4211111        SPC POINT (139.95 17.15)
# 22  CHN   0.4794444        SPC POINT (152.45 17.15)
# 23  CHN   5.6959722        SPC POINT (152.55 17.15)
# 24  CHN   5.9569444        SPC POINT (152.45 17.25)
# 25  TWN  10.5041667        SPC POINT (140.95 17.65)
# 26  CHN   6.0552778        SPC POINT (152.75 18.75)
# 27  CHN   6.0904167        SPC POINT (152.85 18.75)
# 28  CHN   6.4880556        SPC POINT (152.15 18.85)
# 29  CHN   6.1594444        SPC POINT (152.25 18.85)
# 30  JPN   1.1087500        SPC POINT (151.95 19.15)
# ... ...  ...               ... ...
# 909 DONG  0.3818056        SPC POINT (-157.05 -2.65)
# 910 DONG  0.8458333        SPC POINT (-156.95 -2.65)
# 911 DONG  4.8361111        SPC POINT (-156.85 -2.65)
# 912 DONG 10.8247222        SPC POINT (-157.65 -2.55)
# 913 DONG  1.8484722        SPC POINT (-157.55 -2.55)
# 914 DONG  2.7354167        SPC POINT (-157.45 -2.55)
# 915 DONG  7.7358333        SPC POINT (-157.35 -2.55)
# 916 DONG  1.6913889        SPC POINT (-157.25 -2.55)
# 917 DONG  5.2597222        SPC POINT (-157.75 -2.45)
# 918 DONG  0.8238889        SPC POINT (-157.65 -2.45)
# 919 DONG  0.8122222        SPC POINT (-157.55 -2.45)
# 920 DONG  1.0638889        SPC POINT (-157.45 -2.45)
# 921 DONG  0.8658333        SPC POINT (-157.35 -2.45)
# 922 DONG  1.7033333        SPC POINT (-157.25 -2.35)
# 923 DONG  5.2427778        SPC POINT (-165.95 -2.25)
# 924 DONG  1.0902778        SPC POINT (-157.25 -2.25)
# 925 DONG  0.8125000        SPC POINT (-165.95 -2.15)
# 926 DONG  1.2622222        SPC POINT (-157.25 -2.15)
# 927 DONG  0.6043056        SPC POINT (-165.95 -2.05)
# 928 DONG  1.7722222        SPC POINT (-157.25 -2.05)
# 929 DONG  0.8972222        SPC POINT (-157.15 -2.05)
# 930 DONG  2.3119444        SPC POINT (-157.05 -2.05)
# 931 DONG  1.1275000        SPC POINT (-156.95 -2.05)
# 932 DONG  1.7833333        SPC POINT (-156.85 -2.05)
# 933 DONG  1.2608333        SPC POINT (-165.95 -1.95)
# 934 DONG  1.8611111        SPC POINT (-156.75 -1.95)
# 935 DONG  4.5787500        SPC POINT (-170.35 -0.25)
# 936 DONG  1.4016667        SPC POINT (-170.35 -0.15)
# 937 DONG  4.6902778        SPC POINT (-170.45 -0.05)
# 938 DONG  1.2769444        SPC POINT (-170.35 -0.05)

# %%
#projection
p = CRS("+proj=aea +lat_0=-30 +lat_1=30 +lon_0=-180")
wcpfc_map<-st_transform(wcpfc_map, p)
spc<-st_transform(spc, p)
countries<-st_transform(countries, p)
clipped_total<-st_transform(clipped_total, p)

# %%
#DEVELOP COLOR SCALE, CHANGE FROM + to POINTS
#library(RColorBrewer) # creates nice color schemes
#library(classInt) 
#nclr <- 4
#plotclr <- brewer.pal(nclr,"BuPu")
#class <- classIntervals(clipped_total$totalFishingHours, nclr, style="quantile") #clipped #dongwon_clipped
#colcode <- findColours(class, plotclr)
#Create a custom color scale
library(RColorBrewer)
myColors <- brewer.pal(12,"Set3")
names(myColors) <- levels(clipped_total$flag)
colScale <- scale_colour_manual(name = "grp",values = myColors)
myColors
set3 <- colorRampPalette(brewer.pal('Set3',n=12))

#plot(countries, border="wheat3", col="wheat1")
plot(wcpfc_map, border="wheat3", col="lightblue", add=T)
plot(spc, border="wheat3", col="red", add=T)
plot(clipped_total["flag"], pal = sf.colors(15, categorical = TRUE), 
     pch=16, key.pos = 4, key.width = lcm(4.5), axes = TRUE, add=T)

#plot
#map = ggplot() + 
#geom_sf(data = wcpfc_map, fill = "blue", alpha=.5) +
#geom_sf(data = spc, fill = "green", alpha=.5) +
#geom_sf(data = countries, aes(fill = NAME)) +
#geom_sf(data = clipped_total, aes(fill=clipped_total$flag), pch=21) +
#scale_color_manual(values = setNames(set3(15), levels(clipped_total$flag)))
#scale_size_continuous(range=c(1,12))
#theme(legend.position = "none") 
#map

# %%
clipped_total_flag <- clipped_total%>%
  group_by(flag) %>%
  summarise(totalFishingHours=sum(totalFishingHours))
clipped_total_flag
# Out:
# ERROR while rich displaying an object: Error in loadNamespace(name): there is no package called ‘geojsonio’
#
# Traceback:
# 1. FUN(X[[i]], ...)
# 2. tryCatch(withCallingHandlers({
#  .     if (!mime %in% names(repr::mime2repr))
#  .         stop("No repr_* for mimetype ", mime, " in repr::mime2repr")
#  .     rpr <- repr::mime2repr[[mime]](obj)
#  .     if (is.null(rpr))
#  .         return(NULL)
#  .     prepare_content(is.raw(rpr), rpr)
#  . }, error = error_handler), error = outer_handler)
# 3. tryCatchList(expr, classes, parentenv, handlers)
# 4. tryCatchOne(expr, names, parentenv, handlers[[1L]])
# 5. doTryCatch(return(expr), name, parentenv, handler)
# 6. withCallingHandlers({
#  .     if (!mime %in% names(repr::mime2repr))
#  .         stop("No repr_* for mimetype ", mime, " in repr::mime2repr")
#  .     rpr <- repr::mime2repr[[mime]](obj)
#  .     if (is.null(rpr))
#  .         return(NULL)
#  .     prepare_content(is.raw(rpr), rpr)
#  . }, error = error_handler)
# 7. repr::mime2repr[[mime]](obj)
# 8. repr_geojson.sf(obj)
# 9. repr_geojson(geojsonio::geojson_list(obj), ...)
# 10. geojsonio::geojson_list
# 11. getExportedValue(pkg, name)
# 12. asNamespace(ns)
# 13. getNamespace(ns)
# 14. loadNamespace(name)
# 15. withRestarts(stop(cond), retry_loadNamespace = function() NULL)
# 16. withOneRestart(expr, restarts[[1L]])
# 17. doWithOneRestart(return(expr), restart)
#    flag totalFishingHours geometry
# 1  NA    35.9719444       MULTIPOINT (65983.27 101403...
# 2  CHN  747.1956944       MULTIPOINT (-2833367 530526...
# 3  DONG 191.6452778       MULTIPOINT (380028.2 251118...
# 4  ECU    3.5184722       MULTIPOINT (2400940 2565309...
# 5  ESP   15.3765278       MULTIPOINT (3249239 2560296...
# 6  FJI   15.0541667       MULTIPOINT (-827710.7 12226...
# 7  FSM   28.7070833       MULTIPOINT (50794.48 263869...
# 8  JPN   62.6054167       MULTIPOINT (-3068530 562325...
# 9  KIR   44.2473611       MULTIPOINT (1045376 1141364...
# 10 KOR  210.6023611       MULTIPOINT (1354372 2772491...
# 11 MDV    0.5090278       POINT (1007398 3009702)
# 12 PYF   22.0175000       MULTIPOINT (4296608 1032439...
# 13 SLV   14.5459722       MULTIPOINT (2583065 2571981...
# 14 TWN  731.5615278       MULTIPOINT (-4289946 533217...
# 15 USA  172.3613889       MULTIPOINT (770325.3 156250...
# 16 VUT  284.2452778       MULTIPOINT (801619.6 169649...

# %%
#filter aggregated stats to bbox
dongwon_aggregated_bbox<-dongwon_aggregated[which(dongwon_aggregated$lat_bin > -9.84 & dongwon_aggregated$lat_bin < 4.7 & dongwon_aggregated$lon_bin > -176.85 & dongwon_aggregated$lon_bin < -151.41),]
aggregated_bbox<-aggregated[which(aggregated$lat_bin > -9.84 & aggregated$lat_bin < 4.7 & aggregated$lon_bin > -176.85 & aggregated$lon_bin < -151.41),]

aggregated_bbox_flag<-aggregated_bbox%>%
  group_by(flag) %>%
  summarise(totalFishingHours=sum(totalFishingHours))

dongwon_mmsi_BB<-dongwon_fishing[which(dongwon_fishing$lat_bin/10 > -9.84 & dongwon_fishing$lat_bin/10 < 4.7 & dongwon_fishing$lon_bin/10 > -176.85 & dongwon_fishing$lon_bin/10 < -151.41),]
dongwon_mmsi<-dongwon_mmsi_BB %>%
  group_by(mmsi) %>%
  summarise(totalFishingHours=sum(fishing_hours))
